# %% [markdown]
# # **COMP 2211 Exploring Artificial Intelligence** #
# ## Lab 5 Simple Perceptron ##
#
# ![perceptron.png](data:image/png;base64,...)

# %% [markdown]
# ## Before We Begin ##
#
# In this lab, you will learn how to implement the Perceptron model from scratch. Also, we will apply the Perceptron model to different datasets.

# %% [markdown]
# # 1. The Perceptron Model
#
# The training process of a Perceptron model is defined as  follows:
#
# >1. Set initial weight and bias for perceptron
# >2. Predict the label with input variables, weight, and bias
# >3. Update the weight and bias according to the "distance" between the predicted label and the true label
# >4. Repeat steps __2__ and __3__ until we meet the stopping condition
#
# You need to fill the TODOs to implement the Perceptron class, which can be reused for different datasets.
#
# There are 3 functions in the model: `__init__`, `fit` and `predict`.<br>
# >The `__init__` creates the perceptron model and initializes the variables.<br>
# >The `fit` trains the perceptron model by updating the variables in class with a given dataset.<br>
# >The `predict` function calculates the output value based on input and class variables and then returns the class label.

# %% [markdown]
# ## Task 1.1
#
# Initialize the __weights_and_bias__ inside the 'fit' function.
#
# __weights_and_bias__ represents all trainable variables, including "weight", and “bias”. So that the vector length of __weights_and_bias__ should be: <br>
# >1 + the vector length of a row in training vector __X__.
#
# Putting all trainable parameters in one variable is useful when we want to pass, manage, and update them, especially those highly related parameters (e.g. bias and weight will be used and updated simultaneously).

# %% [markdown]
# ## Task 1.2
#
# Define the training function __fit__, which  takes __X__ and __Y__ as inputs to update __weights_and_bias__ for our perceptron model.
#
# The __weights_and_bias__ should be updated according to the value of the data sample in __X__ and the difference between prediction and the true labels:
#
# >1. Predict the label with input features, and class variable __weighs_and_bias__
# >2. Update the __weight_and_bias__ according to the "distance" between the predicted label and true label
# >3. Repeat steps __1__ and __2__ until we meet the stopping condition
#
# Please record the number of mismatching in each epoch to visualize the training process later: <br>
# Checking the error terms __delta__ for each data sample, and putting the count of non-zero ones in each epoch into the error list __errors__.
# > E.g. There are 5 mismatching (__delta__ != 0) in the first epoch, and then we append __5__ to the __errors__.
#
# As mentioned in the review notebook, there are different rules to stop the training process. Please use the following rule on top of stopping the training when meeting __max_epoch__.
# * Stop when $accuracy$ is high enough. Similar to the above, we can count the accuracy level after each epoch. If the accuracy exceeds a certain number, __p__, stop the training process.
#
# Specifically, we set __p__ as __0.98__ and reuse the number of mismatchings in each epoch recorded above to calculate the accuracy.
# >E.g. There are 5 mismatchings (__delta__ != 0) in the first epoch, and there are __n__ data samples in X. Then the accuracy for the first epoch should be $1-\frac{5}{n}$.

# %% [markdown]
# ## Task 1.3
#
# Define the __predict__ function, which takes __X__ as input to calculate and return the prediction.
#
# To do so, you should consider how perceptron uses weight and bias to predict the input label.
#
# As the training process will update the __weights_and_bias__ by looking at each row in the training dataset,  we do not want to use a loop when predicting labels for all test datasets.
#
# Please utilize __.dot()/.matmul()__ function to achieve following:
#
# >1. The __predict__ function can take both matrix and vector as input for __X__.
# >2. The return type of __predict__ function will change according to the type of input __X__ (i.e., a single value for vector input and vector type for matrix input).
#
# If __X__ is an array while __weights_and_bias__ is an array:
#
# __X__:
# \begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
# \end{bmatrix}
#
# __weights_and_bias__:
# \begin{bmatrix}
#     \theta \\
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}
#
# Then, the calculation of prediction in vector form will be like:
#
# $$\begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}+ \theta
# =Y_{1}$$
#
# If __X__ is a matrix (2D array) while __weights_and_bias__ is an array:
#
# __X__:
# \begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
#     x_{21} & x_{22} & x_{23} & \dots  & x_{2n} \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     x_{d1} & x_{d2} & x_{d3} & \dots  & x_{dn}
# \end{bmatrix}
#
# __weights_and_bias__:
# \begin{bmatrix}
#     \theta \\
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}
#
# Then, the calculation of prediction in matrix form will be like this:
#
# $$\begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
#     x_{21} & x_{22} & x_{23} & \dots  & x_{2n} \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     x_{d1} & x_{d2} & x_{d3} & \dots  & x_{dn}
# \end{bmatrix}\cdot
# \begin{bmatrix}
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}+
# \begin{bmatrix}
#     \theta\\
#     \theta\\
#     \vdots \\
#     \theta
# \end{bmatrix}
# =\begin{bmatrix}
#     Y_{1}\\
#     Y_{2}\\
#     \vdots \\
#     Y_{d}
# \end{bmatrix}$$
#
# Do not forget to use an activation function, $f$, to judge the response.
# >$response = f(Y) = 1 $  for  $Y>0$<br/>
# >$response = f(Y) = 0 $  for  $Y\leq0$
#
# Try to use NumPy calculation to construct the function.

# %%
import numpy as np

class MyPerceptron(object):
    def __init__(self,lr = 0.01, epoch = 10, in_weight = 0.0):

        self.lr = lr               # Learning rate
        self.epoch = epoch         # The max epoch of training
        self.in_weight = in_weight # The initial value of weights_and_bias

    def fit(self,X,Y):
        # Fit training data
        # X : Training vectors, X.shape : [#samples, #features]
        # Y : Target values, Y.shape : [#samples]

        # Initialize the weights and bias according to in_weight and length of input data sample
        # Initialize the weights and bias as a NumPy array. 
        # There are different ways to initialize them, i.e. from all 0, all 0.5, all 1, according to in_weight.

        self.weights_and_bias = np.full([X.shape[1] + 1, 1], self.in_weight)
    
        # Initialize the list that records the number of misclassifications for each epoch
        self.errors = []

        # Update the __weights_and_bias__ according to the value of the data sample in the dataset and compute the difference between prediction and true labels
        # Record the number of misclassifications for each epoch

        i = 0; p = 0;
        # Stopping Condition for Learning
        while i < self.epoch and p > 0.98:
            num_dp = 0
            for x in X:
                output = self.predict(x)
                for j in range(len(Y)):
                    if Y[j] != output[x]:
                        # T-O
                        roundError = Y[j] - output[x]

                        # Update Bias
                        self.weights_and_bias[0] += self.lr * roundError

                        # Update Weight
                        self.weights_and_bias[1:] += self.lr * roundError * x[i]

                        # Count number of mismatching data points
                        num_dp += 1
                        print(num_dp)

            # Append numErrors to error list
            self.errors.append(num_dp)
            print(self.errors)

            # Update p for stopping condition
            p = 1 - (num_dp / X.shape[0])
            i += 1
            
        return self
    
    # Calculate the value based on weights and input to return the class label
    def predict(self,X):
        
        y = X.dot(self.weights_and_bias[1:]) + self.weights_and_bias[0]   # np.tile(self.weights_and_bias[0], (X.shape[0], 1))

        # Activation Function
        prediction = (y > 0) * 1.0
        return prediction

# %%
y = np.array([2, -1, 2, 0])
a = (y > 0) * 1
print(a)
# Out:
# [1 0 1 0]

# %%
sample = MyPerceptron(lr = 0.01, epoch = 10, in_weight = 0.0)

# %% [markdown]
# # 2. Prepare the Datasets
#
# After preparing the model, we now have the "gun". It is time to build the "bullets", and various datasets to try out the model.
#
# The datasets we use in this lab are the __Sonar__ and __Iris__ datasets.
#
# The __Sonar__ dataset describes the information collected from a sonar system. The feature variables (those numbers between 0-1) are the strength of the signal from different angles, while the prediction variables (the letter __R__ or __M__) indicate the type of object. <br>
# It is a binary classification that requires a perceptron model to differentiate __rocks__ from __metal__.
#
# The __Iris__ dataset describes the information about 3 kinds of iris plants. The dataset contains 3 classes of 50 instances each. The feature variables (those numbers) are sepal length, sepal width, petal length and petal width, while the prediction variables (the texts) indicate the type of iris plant. <br>
# We will take 2 classes of them as a binary classification that requires a perceptron model to predict.

# %% [markdown]
# Run the following code to load the sonar dataset.

# %%
import pandas as pd
dataset1= pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.all-data', index_col=False, header=None)
dataset1
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# 0    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#          58      59  60
# 0    0.0090  0.0032   R
# 1    0.0052  0.0044   R
# 2    0.0095  0.0078   R
# 3    0.0040  0.0117   R
# 4    0.0107  0.0094   R
# ..      ...     ...  ..
# 203  0.0193  0.0157   M
# 204  0.0062  0.0067   M
# 205  0.0077  0.0031   M
# 206  0.0036  0.0048   M
# 207  0.0061  0.0115   M
#
# [208 rows x 61 columns]

# %% [markdown]
# Run the following code to load the iris dataset.

# %%
import pandas as pd
#dataset= pd.read_csv('iris.csv', index_col=False, header=None)
dataset2 = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)
dataset2=dataset2[:100]
dataset2
# Out:
#       0    1    2    3                4
# 0   5.1  3.5  1.4  0.2      Iris-setosa
# 1   4.9  3.0  1.4  0.2      Iris-setosa
# 2   4.7  3.2  1.3  0.2      Iris-setosa
# 3   4.6  3.1  1.5  0.2      Iris-setosa
# 4   5.0  3.6  1.4  0.2      Iris-setosa
# ..  ...  ...  ...  ...              ...
# 95  5.7  3.0  4.2  1.2  Iris-versicolor
# 96  5.7  2.9  4.2  1.3  Iris-versicolor
# 97  6.2  2.9  4.3  1.3  Iris-versicolor
# 98  5.1  2.5  3.0  1.1  Iris-versicolor
# 99  5.7  2.8  4.1  1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Vector Representation Transformation
# As we can see, the data inputs are in __float__ format, while the labels are in __string__ format. To utilize them to build a model, we need to transform labels into numbers.
#
# The label transformation here is  the LabelEncoder we used in Lab3.
#
# These processes are always called __feature extraction__, which means extracting the features we care about as numbers to put in the model.
#
# Run the following codes to perform the transformation.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

for k in dataset1.keys():
  if(type(dataset1[k][0])==str):
    dataset1[k] = encoder.fit_transform(dataset1[k])

# %%
for k in dataset2.keys():
  if(type(dataset2[k][0])==str):
    dataset2[k] = encoder.fit_transform(dataset2[k])

# %% [markdown]
# Now you can check the numeric data.
# Compare it with the original one to find differences.

# %%
dataset1
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# 0    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#          58      59  60
# 0    0.0090  0.0032   1
# 1    0.0052  0.0044   1
# 2    0.0095  0.0078   1
# 3    0.0040  0.0117   1
# 4    0.0107  0.0094   1
# ..      ...     ...  ..
# 203  0.0193  0.0157   0
# 204  0.0062  0.0067   0
# 205  0.0077  0.0031   0
# 206  0.0036  0.0048   0
# 207  0.0061  0.0115   0
#
# [208 rows x 61 columns]

# %%
dataset2
# Out:
#       0    1    2    3  4
# 0   5.1  3.5  1.4  0.2  0
# 1   4.9  3.0  1.4  0.2  0
# 2   4.7  3.2  1.3  0.2  0
# 3   4.6  3.1  1.5  0.2  0
# 4   5.0  3.6  1.4  0.2  0
# ..  ...  ...  ...  ... ..
# 95  5.7  3.0  4.2  1.2  1
# 96  5.7  2.9  4.2  1.3  1
# 97  6.2  2.9  4.3  1.3  1
# 98  5.1  2.5  3.0  1.1  1
# 99  5.7  2.8  4.1  1.3  1
#
# [100 rows x 5 columns]

# %% [markdown]
# # 3. Fit Perceptron Model for Different Datasets
#
# In this section, you will apply the perceptron model to the dataset mentioned and examine the performance.

# %% [markdown]
# ## Task 3.1: Split the train set and test set
#
# We need to split the data into the vector representation __X__ that doesn't contain the target goal and the target ground truth __Y__.
#
# Then we need to split the __X & Y__ into train set and test set (follow 75% for training to 25% for testing in the sonar dataset, follow 70% for training to 30% for testing in the iris dataset).
#
#
# __Attention__: Applying __random_state__ is important, as it is highly likely to have an imbalanced distribution of data in split sets. You can use __3__ for __random_state__.

# %%
from sklearn.model_selection import train_test_split
np_dataset1=dataset1.to_numpy()

X1 = np_dataset1[:,:-1]
Y1 = np_dataset1[:,-1]
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, random_state=3, train_size = .75)

# %%
np_dataset2=dataset2.to_numpy()

X2 = np_dataset2[:,:-1]
Y2 = np_dataset2[:,-1]
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, random_state=3, train_size = .75)

# %% [markdown]
# ## Visualize the Datasets
# We can plot the iris dataset via two-dimensional scatter for better understanding.

# %%
import matplotlib.pyplot as plt
plt.scatter(X2[:50, 0], X2[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X2[50:100, 0], X2[50:100, 1], color='blue', marker='x', label='versicolor')
plt.xlabel('petal length')
plt.ylabel('sepal length')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# But it is hard to plot the sonar dataset in two-dimensional scatter as it contains 60 categories.

# %%
import matplotlib.pyplot as plt
plt.scatter(X1[:97, 0], X1[:97, 1], color='red', marker='o', label='R')
plt.scatter(X1[97:, 0], X1[97:, 1], color='blue', marker='x', label='M')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Task 3.2: Fit the models
# Initialize and train the perceptron model on the sonar dataset and iris data subset.
#
# To perform initialization and training, you can create an object from the perceptron class, and call the  __fit__ function to train the model.
#
# We define the learning rate and epochs as 0.01 and 500 for the sonar dataset, and all variables in __weights_and_bias__ initialize to 0. <br>
# You can also try other combinations to get your result.
# Different parameters could produce different outcomes.

# %%
# TODO:
#def __init__(self,lr = 0.01, epoch = 10, in_weight = 0.0):
sonar_perceptron = MyPerceptron(lr = 0.01, epoch = 500, in_weight = 0)
sonar_perceptron.fit(X1_train, Y1_train)

# %%
len(Y1_train)
# Out:
# 156

# %%
X1_train.shape[0]
# Out:
# 156

# %% [markdown]
# We will plot the misclassification error for each epoch to check if the algorithm converged and found a decision boundary that separates the two sonar classes.

# %%
plt.plot(range(1, len(sonar_perceptron.errors) + 1), sonar_perceptron.errors, marker='o')
plt.xlabel('Epochs in sonar')
plt.ylabel('Number of misclassifications')
plt.show()

# %% [markdown]
# We define the learning rate and epochs as 0.01 and 20 for the iris dataset, and all variables in __weights_and_bias__ initialize to 0.

# %%
# TODO:
iris_perceptron = MyPerceptron(lr = 0.01, epoch = 200, in_weight = 0)
iris_perceptron.fit(X2_train, Y2_train)

# %% [markdown]
# We will plot the misclassification error for each epoch to check if the algorithm converged and found a decision boundary that separates the two Iris flower classes.

# %%
plt.plot(range(1, len(iris_perceptron.errors) + 1), iris_perceptron.errors, marker='o')
plt.xlabel('Epochs in iris')
plt.ylabel('Number of misclassifications')
plt.show()

# %% [markdown]
# ## Prediction and Evaluate the Performance
#
# Finally,  we can evaluate the test set we split to check our hardworking outcome.

# %%
prediction = sonar_perceptron.predict(X1_test)

# %%
prediction2 = iris_perceptron.predict(X2_test)

# %% [markdown]
# Following is the accuracy metric provided by sklearn.

# %%
from sklearn import metrics
print("accuracy for sonar_perceptron: ", metrics.accuracy_score(Y1_test, prediction))
print("accuracy for iris_perceptron: ", metrics.accuracy_score(Y2_test, prediction2))
# Out:
# accuracy for sonar_perceptron:  0.5576923076923077
# accuracy for iris_perceptron:  0.44

# %% [markdown]
# Let us use another metric to evaluate the performance: The __F1__ score.
#
# __F1__ score is a balance score that cares about precision and recall.

# %%
print("F1 for sonar_perceptron: ", metrics.f1_score(Y1_test, prediction))
print("F1 for iris_perceptron: ", metrics.f1_score(Y2_test, prediction2))
# Out:
# F1 for sonar_perceptron:  0.0
# F1 for iris_perceptron:  0.0

# %% [markdown]
# # Perceptron in sklearn
# You can change the __in_weight__, __lr__, __epoch__.... and run the training process again.
#
# With different parameter settings, you may get different accuracy scores.
#
# As you do not need to submit this lab, we will  use the accuracy score from the perceptron model under sklearn as a reference.

# %%
from sklearn.linear_model import Perceptron

input = X1_train
output = Y1_train
weights = {0:0.1,1:0.5}
model = Perceptron(class_weight=weights, eta0=0.1)
model.fit(input,output)
prediction2 = model.predict(X1_test)

# %%
print(metrics.accuracy_score(Y1_test, prediction2))
# Out:
# 0.7307692307692307
